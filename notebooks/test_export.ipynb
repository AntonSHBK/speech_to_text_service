# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parent))


from pathlib import Path
from app.utils.export import export_result

result = {
    "language": "ru",
    "duration": 5483.42,
    "text": (
        "Вашему вниманию представляется проект системы группового управления беспилотными "
        "летательными аппаратами. В современной индустрии БПЛА существует проблема "
        "недостатка операторов и масштабируемых систем мониторинга."
    ),
    "segments": [
        {"start": 0.000, "end": 4.200, "text": "Вашему вниманию представляется проект системы группового"},
        {"start": 4.200, "end": 8.850, "text": "управления беспилотными летательными аппаратами."},
        {"start": 8.850, "end": 14.120, "text": "В современной индустрии БПЛА существует проблема"},
        {"start": 14.120, "end": 18.940, "text": "недостатка операторов и масштабируемых систем мониторинга."},
        {"start": 18.940, "end": 24.700, "text": "Предлагаемая платформа решает задачу координации нескольких дронов."},
        {"start": 24.700, "end": 31.100, "text": "Архитектура включает модуль планирования, модуль связи и аналитическое ядро."},
        {"start": 31.100, "end": 39.560, "text": "Система поддерживает работу в условиях ограниченного канала и частичных отказов."},
        {"start": 39.560, "end": 48.000, "text": "Полевые испытания показали рост эффективности выполнения миссий на 37 процентов."},
    ],
    "diarization": {
        "duration": 48.0,
        "num_speakers": 3,
        "speakers": ["SPEAKER_00", "SPEAKER_01", "SPEAKER_02"],
        "segments": [
            {"speaker": "SPEAKER_00", "start": 0.000, "end": 9.000, "duration": 9.000},
            {"speaker": "SPEAKER_01", "start": 9.000, "end": 19.300, "duration": 10.300},
            {"speaker": "SPEAKER_00", "start": 19.300, "end": 27.000, "duration": 7.700},
            {"speaker": "SPEAKER_02", "start": 27.000, "end": 40.100, "duration": 13.100},
            {"speaker": "SPEAKER_01", "start": 40.100, "end": 48.000, "duration": 7.900},
        ],
        "exclusive_segments": [
            {"speaker": "SPEAKER_00", "start": 0.000, "end": 8.700, "duration": 8.700},
            {"speaker": "SPEAKER_01", "start": 8.700, "end": 18.900, "duration": 10.200},
            {"speaker": "SPEAKER_00", "start": 18.900, "end": 26.800, "duration": 7.900},
            {"speaker": "SPEAKER_02", "start": 26.800, "end": 39.800, "duration": 13.000},
            {"speaker": "SPEAKER_01", "start": 39.800, "end": 48.000, "duration": 8.200},
        ],
        "processing_time": 5.73,
    },
    "meta": {
        "source": "demo_long_video.mp4",
        "model": "large-v3",
        "task": "transcribe",
        "word_timestamps": False,
        "notes": {
            "domain": "uav",
            "quality": "clean",
            "noise_level": "low",
        },
    },
}

out_dir = Path("./tmp_test_export")
out_dir.mkdir(parents=True, exist_ok=True)

# txt/md уже учитывают export_timestamps в вашем текущем коде
export_result(result, out_dir / "result_ts.txt", format="txt", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.txt", format="txt", export_timestamps=False)
export_result(result, out_dir / "result_ts.md", format="md", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.md", format="md", export_timestamps=False)



export_result(result, out_dir / "result.docx", format="docx", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.docx", format="docx", export_timestamps=False)
export_result(result, out_dir / "result.pdf", format="pdf", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.pdf", format="pdf", export_timestamps=False)

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parent))


from pathlib import Path
from app.utils.export import export_result

result = {
    "language": "ru",
    "duration": 5483.42,
    "text": (
        "Вашему вниманию представляется проект системы группового управления беспилотными "
        "летательными аппаратами. В современной индустрии БПЛА существует проблема "
        "недостатка операторов и масштабируемых систем мониторинга."
    ),
    "segments": [
        {"start": 0.000, "end": 4.200, "text": "Вашему вниманию представляется проект системы группового"},
        {"start": 4.200, "end": 8.850, "text": "управления беспилотными летательными аппаратами."},
        {"start": 8.850, "end": 14.120, "text": "В современной индустрии БПЛА существует проблема"},
        {"start": 14.120, "end": 18.940, "text": "недостатка операторов и масштабируемых систем мониторинга."},
        {"start": 18.940, "end": 24.700, "text": "Предлагаемая платформа решает задачу координации нескольких дронов."},
        {"start": 24.700, "end": 31.100, "text": "Архитектура включает модуль планирования, модуль связи и аналитическое ядро."},
        {"start": 31.100, "end": 39.560, "text": "Система поддерживает работу в условиях ограниченного канала и частичных отказов."},
        {"start": 39.560, "end": 48.000, "text": "Полевые испытания показали рост эффективности выполнения миссий на 37 процентов."},
    ],
    "meta": {
        "source": "demo_long_video.mp4",
        "model": "large-v3",
        "task": "transcribe",
        "word_timestamps": False,
        "notes": {
            "domain": "uav",
            "quality": "clean",
            "noise_level": "low",
        },
    },
}

out_dir = Path("./tmp_test_export")
out_dir.mkdir(parents=True, exist_ok=True)

# txt/md уже учитывают export_timestamps в вашем текущем коде
export_result(result, out_dir / "result_ts.txt", format="txt", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.txt", format="txt", export_timestamps=False)
export_result(result, out_dir / "result_ts.md", format="md", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.md", format="md", export_timestamps=False)



export_result(result, out_dir / "result.docx", format="docx", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.docx", format="docx", export_timestamps=False)
export_result(result, out_dir / "result.pdf", format="pdf", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.pdf", format="pdf", export_timestamps=False)

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parent))


from pathlib import Path
from app.utils.export import export_result

result = {
    "language": "ru",
    "duration": 92.4,
    "text": (
        "Добрый день коллеги сегодня мы разберем архитектуру сервиса и план релиза. "
        "После этого обсудим риски и распределение задач между командами. "
        "Далее перейдем к вопросам по инфраструктуре и нагрузочному тестированию. "
        "Затем согласуем дедлайны и критерии готовности этапов."
    ),
    "segments": [
        # SPEAKER_00 — длинная фраза
        {"start": 0.0, "end": 7.2, "text": "Добрый день коллеги сегодня мы разберем архитектуру сервиса"},
        {"start": 7.2, "end": 14.0, "text": "и план релиза чтобы команда разработки и команда аналитики"},
        {"start": 14.0, "end": 19.8, "text": "синхронизировали приоритеты и зависимые задачи"},

        # пауза > 2с => новый абзац (тот же спикер)
        {"start": 22.5, "end": 29.6, "text": "Отдельно хочу подчеркнуть что в этом цикле важна стабильность"},
        {"start": 29.6, "end": 35.9, "text": "и прозрачная коммуникация между backend и devops командами"},

        # SPEAKER_01 — длинная фраза
        {"start": 36.1, "end": 43.5, "text": "Согласен и предлагаю в первую очередь закрыть вопросы по метрикам"},
        {"start": 43.5, "end": 49.7, "text": "чтобы мы могли объективно оценить влияние оптимизаций"},
        {"start": 49.7, "end": 56.8, "text": "на время отклика и на устойчивость под пиковыми запросами"},

        # пауза > 2с => новый абзац (тот же спикер)
        {"start": 59.6, "end": 66.2, "text": "После этого мы обновим стенд и повторим полный цикл тестирования"},
        {"start": 66.2, "end": 72.8, "text": "с фиксацией всех отклонений в едином отчете для руководства"},

        # снова SPEAKER_00
        {"start": 73.0, "end": 80.0, "text": "Хорошо тогда финализируем дорожную карту и точки контроля"},
        {"start": 80.0, "end": 86.4, "text": "а также закрепим ответственных по каждому направлению"},
        {"start": 86.4, "end": 92.4, "text": "чтобы в конце спринта получить предсказуемый результат"},
    ],
    # "diarization": {
    #     "duration": 92.4,
    #     "num_speakers": 2,
    #     "speakers": ["SPEAKER_00", "SPEAKER_01"],
    #     "segments": [
    #         {"speaker": "SPEAKER_00", "start": 0.0, "end": 35.9, "duration": 35.9},
    #         {"speaker": "SPEAKER_01", "start": 36.1, "end": 72.8, "duration": 36.7},
    #         {"speaker": "SPEAKER_00", "start": 73.0, "end": 92.4, "duration": 19.4},
    #     ],
    #     "exclusive_segments": [
    #         {"speaker": "SPEAKER_00", "start": 0.0, "end": 35.9, "duration": 35.9},
    #         {"speaker": "SPEAKER_01", "start": 36.1, "end": 72.8, "duration": 36.7},
    #         {"speaker": "SPEAKER_00", "start": 73.0, "end": 92.4, "duration": 19.4},
    #     ],
    #     "processing_time": 4.8,
    # },
}


out_dir = Path("./tmp_test_export")
out_dir.mkdir(parents=True, exist_ok=True)

# txt/md уже учитывают export_timestamps в вашем текущем коде
export_result(result, out_dir / "result_ts.txt", format="txt", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.txt", format="txt", export_timestamps=False)
export_result(result, out_dir / "result_ts.md", format="md", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.md", format="md", export_timestamps=False)



export_result(result, out_dir / "result.docx", format="docx", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.docx", format="docx", export_timestamps=False)
export_result(result, out_dir / "result.pdf", format="pdf", export_timestamps=True)
export_result(result, out_dir / "result_no_ts.pdf", format="pdf", export_timestamps=False)
# Out:
# WindowsPath('tmp_test_export/result_no_ts.pdf')
